# %%
import pandas as pd
import numpy as np

# Configuring pandas library
pd.options.display.max_columns = 100
pd.options.display.precision = 4

# %%
path = 'data/final_data_rev/test/'
DF_activity = pd.read_csv(path+'test_activity.csv')

# %%
DF_label = DF_activity.copy()
DF_label = DF_label.drop_duplicates('acc_id').reset_index(drop=True)
DF_label['label'] = [np.nan for i in range(40000)]
DF_label = DF_label[['acc_id', 'label']]
DF_label
# Out:
#                                                   acc_id  label
# 0      6ac252acf5ce113d2eb251d62ee2713c269655be3f8bec...    NaN
# 1      be14d8ed6f435440d8b8e50b3997a30682a113458204e4...    NaN
# 2      911660b6ab8860b6d27fe2ff17d715938b33f261919bf1...    NaN
# 3      9f8fefd8917c0406b108e95cb578d46ea9b360e39200e9...    NaN
# 4      6a3f52c863e97184ee8487c34b59c364e8427724aa29b8...    NaN
# 5      b05933d268fdf4c92fd6331992f2ecda41e1c28d12eb40...    NaN
# 6      14cf6302887cd135a6a312caace5608af778e40a17e889...    NaN
# 7      1f440d69c125b3d99f85add756cbbe1e4e46921fb16dfd...    NaN
# 8      fe2a2e260e89ae26684ec33ebb239a52b366f4db05553f...    NaN
# 9      0662a8c684c6de4f0f92012409a48f5340658e21ea5078...    NaN
# 10     6edd8b5081fed6f1f3ec9ab3bc20a655ee74e5306ac38c...    NaN
# 11     964ad0a4281180e14404637e6617b3f7c4b313ce02e761...    NaN
# 12     1ce464ee310e76d4336e45c31d3731f5d227caff501da9...    NaN
# 13     47fbcf0a0f2081bd85fa4c4bd9b8318742246512f8ee46...    NaN
# ...

# %%
week = 1
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_label, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 1 week : 13502

# %%
week = 2
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_merge, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 2 week : 17116

# %%
week = 3
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_merge, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 3 week : 18362

# %%
week = 4
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_merge, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 4 week : 20390

# %%
week = 5
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_merge, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 5 week : 20928

# %%
week = 6
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_merge, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 6 week : 20191

# %%
week = 7
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_merge, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 7 week : 25142

# %%
week = 8
DF_week_activity = DF_activity[DF_activity['wk'] == week]

DF_week_activity_groupby = DF_week_activity.groupby('acc_id').agg('sum')
DF_week_activity_groupby = DF_week_activity_groupby.reset_index()
DF_week_activity_groupby = DF_week_activity_groupby.drop('wk', axis = 1)

print("the number of player on {} week : {}".format(week, DF_week_activity_groupby.shape[0]))

col = DF_week_activity_groupby.columns.tolist()
for i in range(len(col)):
    if (col[i] != 'acc_id'):
        col[i] = 'wk'+str(week)+'_'+col[i]      
DF_week_activity_groupby.columns = col

DF_merge = pd.merge(left = DF_merge, right = DF_week_activity_groupby, how='left', on = 'acc_id')
# Out:
# the number of player on 8 week : 40000

# %%
DF_merge
# Out:
#                                                   acc_id  label  wk1_cnt_dt  \
# 0      6ac252acf5ce113d2eb251d62ee2713c269655be3f8bec...    NaN         6.0
# 1      be14d8ed6f435440d8b8e50b3997a30682a113458204e4...    NaN         NaN
# 2      911660b6ab8860b6d27fe2ff17d715938b33f261919bf1...    NaN         5.0
# 3      9f8fefd8917c0406b108e95cb578d46ea9b360e39200e9...    NaN         5.0
# 4      6a3f52c863e97184ee8487c34b59c364e8427724aa29b8...    NaN         7.0
# 5      b05933d268fdf4c92fd6331992f2ecda41e1c28d12eb40...    NaN         6.0
# 6      14cf6302887cd135a6a312caace5608af778e40a17e889...    NaN         3.0
# 7      1f440d69c125b3d99f85add756cbbe1e4e46921fb16dfd...    NaN         NaN
# 8      fe2a2e260e89ae26684ec33ebb239a52b366f4db05553f...    NaN         7.0
# 9      0662a8c684c6de4f0f92012409a48f5340658e21ea5078...    NaN         NaN
# 10     6edd8b5081fed6f1f3ec9ab3bc20a655ee74e5306ac38c...    NaN         NaN
# ...

# %%
DF_merge.to_csv(path+'activity.csv', encoding=False, index = False)
'''
DF_merge.fillna().to_csv(path+'activity.csv', encoding=False, index = False)
'''
# Out:
# "\nDF_merge.fillna().to_csv(path+'activity.csv', encoding=False, index = False)\n"
