# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'data/final_data_rev/test/'
DF = pd.read_csv(path + 'test_trade.csv')
DF_L=pd.read_csv(path + 'test_label.csv')

# %%
IT=['grocery','money','weapon','gem','costume','accessory']

# %%
DF=DF.drop(['trade_day','trade_time'],axis=1)

# %%
for week in range(1,9):
    DF_W=DF[DF['trade_week']==week]
    for type in IT:
        DF_W_it=DF_W[DF_W['item_type']==type]
        DF_W_it_S=DF_W_it.groupby('source_acc_id').agg('sum')
        DF_W_it_S=DF_W_it_S.drop('trade_week',axis=1)
        DF_W_it_S=DF_W_it_S.reset_index()
        DF_W_it_S.columns=['acc_id', 'wk' + str(week)+'_source_'+type]
        DF_L = pd.merge(left = DF_L, right = DF_W_it_S, on='acc_id', how='left')
        DF_W_it_T=DF_W_it.groupby('target_acc_id').agg('sum')
        DF_W_it_T=DF_W_it_T.drop('trade_week',axis=1)
        DF_W_it_T=DF_W_it_T.reset_index()
        DF_W_it_T.columns=['acc_id','wk' + str(week)+'_target_'+type]
        DF_L = pd.merge(left = DF_L, right = DF_W_it_T, on='acc_id', how='left')

# %%
DF_L.head()
# Out:
#                                               acc_id  label  \
# 0  6ac252acf5ce113d2eb251d62ee2713c269655be3f8bec...    NaN
# 1  be14d8ed6f435440d8b8e50b3997a30682a113458204e4...    NaN
# 2  911660b6ab8860b6d27fe2ff17d715938b33f261919bf1...    NaN
# 3  9f8fefd8917c0406b108e95cb578d46ea9b360e39200e9...    NaN
# 4  6a3f52c863e97184ee8487c34b59c364e8427724aa29b8...    NaN
#
#    wk1_source_grocery  wk1_target_grocery  wk1_source_money  wk1_target_money  \
# 0           -2.704591                 NaN         -2.542174               NaN
# 1                 NaN                 NaN               NaN               NaN
# 2                 NaN                 NaN         -0.250736          6.849002
# 3           -0.788843                 NaN         -0.774895               NaN
# 4                 NaN                 NaN               NaN               NaN
#
#    wk1_source_weapon  wk1_target_weapon  wk1_source_gem  wk1_target_gem  \
# 0                NaN                NaN             NaN             NaN
# 1                NaN                NaN             NaN             NaN
# 2                NaN                NaN             NaN             NaN
# 3                NaN                NaN             NaN             NaN
# 4                NaN                NaN             NaN             NaN
#
#            ...           wk8_source_money  wk8_target_money  \
# 0          ...                  -2.503332               NaN
# 1          ...                        NaN               NaN
# 2          ...                  -0.476592          0.045296
# 3          ...                  -0.431228               NaN
# 4          ...                        NaN         -0.095318
#
#    wk8_source_weapon  wk8_target_weapon  wk8_source_gem  wk8_target_gem  \
# 0                NaN                NaN             NaN             NaN
# 1                NaN                NaN             NaN             NaN
# 2                NaN                NaN             NaN             NaN
# 3                NaN                NaN             NaN             NaN
# 4                NaN                NaN             NaN             NaN
#
#    wk8_source_costume  wk8_target_costume  wk8_source_accessory  \
# 0                 NaN                 NaN                   NaN
# 1                 NaN                 NaN                   NaN
# 2                 NaN                 NaN                   NaN
# 3                 NaN                 NaN                   NaN
# 4                 NaN                 NaN                   NaN
#
#    wk8_target_accessory
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 98 columns]

# %%
DF_L.to_csv(path+'trade.csv', encoding = False, index = False)
