# %% [markdown]
# # 목차
# ## 1.[Data 불러오기](#1)
# ## 2.[Data 크기 및 모습 확인](#2)
# ## 3.[파티 지속 시간 계산을 위한 전처리](#3)

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# ## 1. Data 불러오기<a name = 1></a>

# %%
path = 'data/final_data_rev/train/'
DF_train_party = pd.read_csv(path+'train_party.csv')
DF_train_label = pd.read_csv(path+'train_label.csv')

# %% [markdown]
# ## 2. Data 크기 및 모습 확인<a name = 2></a>

# %%
print("DF_train_party shape : ", DF_train_party.shape)
DF_train_party.head(5)
# Out:
# DF_train_party shape :  (6962341, 7)
#    party_start_week  party_start_day party_start_time  party_end_week  \
# 0                 1                1     09:14:58.558               1
# 1                 3                3     11:05:05.176               3
# 2                 3                6     02:18:43.172               3
# 3                 4                1     09:22:01.936               4
# 4                 4                5     06:29:21.182               4
#
#    party_end_day party_end_time  \
# 0              1   09:41:30.200
# 1              3   13:07:42.515
# 2              6   02:28:58.177
# 3              1   09:47:40.192
# 4              5   06:50:55.004
#
#                                               hashed
# 0  11fc85879e5ac9d5c83bfba10d73c4c84c154b9f4d9e1d...
# 1  7176c1516207692857535c30a4650b8e8e586af1fed0fd...
# 2  8092e194a750aae539862ed4405f67a6dd5b492e7e57e3...
# 3  4ec597c569b92bd0e1bae4e2a06e13b9657fb81795e194...
# 4  a4b6aea6cb58e43911e7cb7d6c0497197db7c4ed16e1c9...

# %% [markdown]
# ## 3. 파티 지속 시간 계산을 위한 전처리<a name = 3></a>
# ### 순서
# - 그냥 `24 * (end_day - start_day)`와 `end_time - start_time`으로는 기간을 계산할 수 없다.(1일 23시 시작 2일 01시 종료는 2시간)<br/>
# - 따라서 `week`와 `day`를 순서쌍으로 1월 1일부터 2월 25일까지 매핑해준다<br/>
# ![img](img/calender.png)
# - 다음으로 시간 계산을 위해서 데이터 타입을 str에서 datetime으로 변환해준다<br/>
# - `end - start`로 시간 계산

# %%
temp = 7*(DF_train_party['party_start_week'].values - 1) + (DF_train_party['party_start_day'].values)
temp_month = np.array([1 for i in range(temp.shape[0])])

for i in range(temp.shape[0]):
    if temp[i] > 31:
        temp[i] = temp[i] % 31
        temp_month[i] += 1

temp = temp.astype('str')
temp_month = temp_month.astype('str')

for i in range(temp.shape[0]):
    temp[i] = temp_month[i]+'-'+temp[i]+' '

temp = temp + DF_train_party['party_start_time'] 

DF_train_party['start'] = temp

# %% [markdown]
# ~~~ python
# temp = 7*(DF_train_party['party_start_week'].values - 1) + (DF_train_party['party_start_day'].values)
# temp_month = np.array([1 for i in range(temp.shape[0])])
# ~~~
#
# `temp`에는 week와 day를 사용해서 새로운 day를 저장하여 초기화(ex. 1주 1일 => 1일, 8주 7일 => 56일, 16주 2일 => 37일)<br/>
# `temp_month`에는 1로 초기화. 괄호 안 `[1 for i in range(temp.shape[0])]` 은 1을 temp.shape[0]번 만큼 배열에 넣는다는 의미<br/>
# <hr/>
#
# ~~~ python
# for i in range(temp.shape[0]):
#     if temp[i] > 31:
#         temp[i] = temp[i] % 31
#         temp_month[i] += 1
# ~~~
# `temp[i]`가 31을 넘어가면 2월로 넘기는 작업. 이해하기 쉽쥬?<br/>
# <hr/>
#
# ~~~ python
# temp = temp.astype('str')
# temp_month = temp_month.astype('str')
# ~~~
# 파티 생성 시각과 합쳐주기 위해서 `astype` 메서드를 통해 str 타입으로 변환<br/>
# <hr/>
#
# ~~~ python
# for i in range(temp.shape[0]):
#     temp[i] = temp_month[i]+'-'+temp[i]+' '
# ~~~
# 날짜와 시각을 더했을 때 필요한 공백 추가<br/>
# <hr/>
#
# ~~~ python
# temp = temp + DF_train_party['party_start_time']
# ~~~
# 날짜와 시각 더하기

# %%
temp = 7*(DF_train_party['party_end_week'].values - 1) + (DF_train_party['party_end_day'].values)
temp_month = np.array([1 for i in range(temp.shape[0])])

for i in range(temp.shape[0]):
    if temp[i] > 31:
        temp[i] = temp[i] % 31
        temp_month[i] += 1

temp = temp.astype('str')
temp_month = temp_month.astype('str')

for i in range(temp.shape[0]):
    temp[i] = temp_month[i]+'-'+temp[i]+' '

temp = temp + DF_train_party['party_end_time']  

DF_train_party['end'] = temp

# %% [markdown]
# 위와 동일

# %%
DF_train_party['start'] = pd.to_datetime(DF_train_party['start'], format="%m-%d %H:%M:%S.%f")
DF_train_party['end'] = pd.to_datetime(DF_train_party['end'], format="%m-%d %H:%M:%S.%f")

# %% [markdown]
# str -> datetime 으로 전환

# %%
DF_train_party.head()
# Out:
#    party_start_week  party_start_day party_start_time  party_end_week  \
# 0                 1                1     09:14:58.558               1
# 1                 3                3     11:05:05.176               3
# 2                 3                6     02:18:43.172               3
# 3                 4                1     09:22:01.936               4
# 4                 4                5     06:29:21.182               4
#
#    party_end_day party_end_time  \
# 0              1   09:41:30.200
# 1              3   13:07:42.515
# 2              6   02:28:58.177
# 3              1   09:47:40.192
# 4              5   06:50:55.004
#
#                                               hashed                   start  \
# 0  11fc85879e5ac9d5c83bfba10d73c4c84c154b9f4d9e1d... 1900-01-01 09:14:58.558
# 1  7176c1516207692857535c30a4650b8e8e586af1fed0fd... 1900-01-17 11:05:05.176
# 2  8092e194a750aae539862ed4405f67a6dd5b492e7e57e3... 1900-01-20 02:18:43.172
# 3  4ec597c569b92bd0e1bae4e2a06e13b9657fb81795e194... 1900-01-22 09:22:01.936
# 4  a4b6aea6cb58e43911e7cb7d6c0497197db7c4ed16e1c9... 1900-01-26 06:29:21.182
#
#                       end
# 0 1900-01-01 09:41:30.200
# 1 1900-01-17 13:07:42.515
# 2 1900-01-20 02:28:58.177
# 3 1900-01-22 09:47:40.192
# 4 1900-01-26 06:50:55.004

# %%
'''
DF_train_party = DF_train_party.drop(['party_start_week', 'party_start_day', 'party_start_time', 
                                      'party_end_week', 'party_end_day', 'party_end_time'], axis = 1)
DF_train_party.head()
'''
DF_train_party = DF_train_party.drop(['party_start_day', 'party_start_time', 'party_end_day', 'party_end_time'], axis = 1)
DF_train_party.head()
# Out:
#    party_start_week  party_end_week  \
# 0                 1               1
# 1                 3               3
# 2                 3               3
# 3                 4               4
# 4                 4               4
#
#                                               hashed                   start  \
# 0  11fc85879e5ac9d5c83bfba10d73c4c84c154b9f4d9e1d... 1900-01-01 09:14:58.558
# 1  7176c1516207692857535c30a4650b8e8e586af1fed0fd... 1900-01-17 11:05:05.176
# 2  8092e194a750aae539862ed4405f67a6dd5b492e7e57e3... 1900-01-20 02:18:43.172
# 3  4ec597c569b92bd0e1bae4e2a06e13b9657fb81795e194... 1900-01-22 09:22:01.936
# 4  a4b6aea6cb58e43911e7cb7d6c0497197db7c4ed16e1c9... 1900-01-26 06:29:21.182
#
#                       end
# 0 1900-01-01 09:41:30.200
# 1 1900-01-17 13:07:42.515
# 2 1900-01-20 02:28:58.177
# 3 1900-01-22 09:47:40.192
# 4 1900-01-26 06:50:55.004

# %%
DF_train_party['time'] = DF_train_party['end'].values - DF_train_party['start'].values
DF_train_party.head()
# Out:
#    party_start_week  party_end_week  \
# 0                 1               1
# 1                 3               3
# 2                 3               3
# 3                 4               4
# 4                 4               4
#
#                                               hashed                   start  \
# 0  11fc85879e5ac9d5c83bfba10d73c4c84c154b9f4d9e1d... 1900-01-01 09:14:58.558
# 1  7176c1516207692857535c30a4650b8e8e586af1fed0fd... 1900-01-17 11:05:05.176
# 2  8092e194a750aae539862ed4405f67a6dd5b492e7e57e3... 1900-01-20 02:18:43.172
# 3  4ec597c569b92bd0e1bae4e2a06e13b9657fb81795e194... 1900-01-22 09:22:01.936
# 4  a4b6aea6cb58e43911e7cb7d6c0497197db7c4ed16e1c9... 1900-01-26 06:29:21.182
#
#                       end            time
# 0 1900-01-01 09:41:30.200 00:26:31.642000
# 1 1900-01-17 13:07:42.515 02:02:37.339000
# 2 1900-01-20 02:28:58.177 00:10:15.005000
# 3 1900-01-22 09:47:40.192 00:25:38.256000
# 4 1900-01-26 06:50:55.004 00:21:33.822000

# %% [markdown]
# 이해하는데 어려움이 없을 것이라고 생각합니다.<br/>
# 나중에 datetime 타입은 연산하는데 불편하므로 소수로 다 바꿔버리겠습니다.

# %%
temp = []
for i in range(DF_train_party.shape[0]):
    a = DF_train_party.loc[i,'time']
    a = a.total_seconds()/60
    temp.append(a)
DF_train_party['minutes'] = temp

# %%
DF_train_party['minutes'] = DF_train_party['minutes'].astype('float64')
DF_train_party.head()
# Out:
#    party_start_week  party_end_week  \
# 0                 1               1
# 1                 3               3
# 2                 3               3
# 3                 4               4
# 4                 4               4
#
#                                               hashed                   start  \
# 0  11fc85879e5ac9d5c83bfba10d73c4c84c154b9f4d9e1d... 1900-01-01 09:14:58.558
# 1  7176c1516207692857535c30a4650b8e8e586af1fed0fd... 1900-01-17 11:05:05.176
# 2  8092e194a750aae539862ed4405f67a6dd5b492e7e57e3... 1900-01-20 02:18:43.172
# 3  4ec597c569b92bd0e1bae4e2a06e13b9657fb81795e194... 1900-01-22 09:22:01.936
# 4  a4b6aea6cb58e43911e7cb7d6c0497197db7c4ed16e1c9... 1900-01-26 06:29:21.182
#
#                       end            time     minutes
# 0 1900-01-01 09:41:30.200 00:26:31.642000   26.527367
# 1 1900-01-17 13:07:42.515 02:02:37.339000  122.622317
# 2 1900-01-20 02:28:58.177 00:10:15.005000   10.250083
# 3 1900-01-22 09:47:40.192 00:25:38.256000   25.637600
# 4 1900-01-26 06:50:55.004 00:21:33.822000   21.563700

# %% [markdown]
# 연산 속도를 위해 `minutes`와 `party_members_acc_id`열을 제외하고 다 지우겠습니다.

# %%
DF_train_party.drop(['start', 'end', 'time'], axis =1, inplace = True)
DF_train_party.to_csv(path+'party_temp2.csv', encoding=False, index=False)
